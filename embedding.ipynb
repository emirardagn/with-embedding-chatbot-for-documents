# %%
import pandas as pd
import json
with open('surya/belge2/results.json', 'r', encoding="utf-8-sig") as f:
    data = json.load(f)


data = data["belge2"][0]["text_lines"]


df = pd.DataFrame(columns=["text","bbox","c-x","c-y"])
for d in data:
    df.loc[len(df)] = d["text"],d["bbox"],d["bbox"][0]+d["bbox"][2],d["bbox"][1]+d["bbox"][3]

df["c-x"] = df["c-x"]/2
df["c-y"] = df["c-y"]/2

last_line = float('-inf')
lines =[]
for i in range (len(df)):
    #her bir kelime için
    l_i = df.loc[i]
    if(l_i["c-y"]-last_line >4):
        last_line = l_i["c-y"]
        arr=pd.DataFrame(columns=["text","c-x"])
        arr.loc[len(arr)]= l_i["text"],l_i["c-x"]
        for j in range(i+1,len(df)):
            #diğer kelimeleri
            l_j = df.loc[j]
            #aynı satırdaysa    
            if (abs(l_i["c-y"]-l_j["c-y"]) < 4):
                arr.loc[len(arr)]= l_j["text"],l_j["c-x"]
                
    
        df_sorted = arr.sort_values(by='c-x')
        t = ""
        for value in df_sorted['text']:
            t+=" "+value
        lines.append(t)


lines = [text.lower() for text in lines]

# %%
df['x-start'] = df['bbox'].apply(lambda x: x[0])
df_sorted = df.sort_values(by='x-start')
dif = float("-inf")
df_sorted = df.sort_values(by='x-start').reset_index(drop=True)
columns = []
for i in range (len(df_sorted)):
    l_i = df_sorted.loc[i]
    #farklı bir sütunsa
    if(l_i["x-start"]-dif > 15):
        dif = l_i["x-start"]
        arr = pd.DataFrame(columns=["text","x-start","c-y"])
        arr.loc[len(arr)] = l_i["text"],l_i["x-start"],l_i["c-y"]

        for j in range(len(df_sorted)):
            if (i!=j):
                #diğer kelimeleri
                l_j = df.loc[j]
                #aynı sütundalarsa  
                if (abs(l_i["x-start"]-l_j["x-start"]) < 15):
                    arr.loc[len(arr)]= l_j["text"],l_j["x-start"],l_j["c-y"]
                    
    
        arr = arr.sort_values(by='c-y').reset_index(drop=True)

        t = ""

        for value in arr['text']:
            t+=" "+value
        columns.append(t)

        



for i in range(len(columns)):
    columns[i] = str(i)+".sütun ,"+ str(columns[i])

columns = [text.lower() for text in columns]
columns
# Out:
# ['0.sütun , kdv, harç, damga vergisi ve değerli kağıt bedeli makbuz karşılığı tahsil edilmiştir.\neb26 a / š yazı : 2 / 3  kod: 4.1.1 nbs 20240503958946 nbs 20240503958946',
#  '1.sütun , 13 beykoz 2.  noteri kavacik mah. orhan\n     veli kanik cad. mi̇hrabat i̇ş merkezi̇ mi̇hrabat i̇ş merkezi̇ n:84 k:1 beykoz / tel:+902165378160 fax:+902165378161',
#  '2.sütun , beykoz 2.  noteri yunus tutar yunus tutar n:84 k:1 beykoz / istanbul tel:+902165378160 fax:+902165378161',
#  '3.sütun , 14 14',
#  '6.sütun , türkiye cumhuriyeti türkiye cumhuriyeti atinin kivtiyetini vonli yalçinkaya ile 950018010 vergi numaralı yes oto ki̇ralama ve turi̇zm bu örnek dairede saklı aynı tarih ve yevmiye numaralı aslının aynıdır.',
#  '7.sütun , : normal : yolcu nakli beykoz 2. noteri: k beykoz 2. noteri: k yunus tutar',
#  '8.sütun , : 34dcl612 :toyota : otomobi̇l-aa sedanti̇pi̇ : 2zrw479186 : nmtbz3be40r054731 : nmtbz3be40r054731 : normal : yolcu nakli :fd331661 numaralı motorlu araç tescil belgesi :1441284 :937.276,00 dokuzyüzotuzyedibinikiyüzyetmişaltı türk lirası kdv dahil yunus tutar',
#  '9.sütun , araç satiş sözleşmi araç satiş sözleşmi',
#  '10.sütun , 5 modeli 5 modeli yakit ci̇nsi̇ yeni k. amaci : hususi yeni̇ s. türü  yni k. şekli ',
#  '11.sütun , ornektir ornektir',
#  '12.sütun , vardır 9 alici 9 alici nursel ata 14321632406 zümrütevler mah. emek cad. no: 93/8 / 67 maltepe / istanbul 50533 433 39 60 imza',
#  '13.sütun , : 2020 : ze1ee(eu.m) : benzinelektri : normai : yolcu nakli̇ : yolcu nakli̇',
#  '14.sütun , beykoz 2. noteri̇ resmi muhur imza ) resmi muhur imza )',
#  '15.sütun , beykoz 2. noteri̇ yunus tutar yunus tutar',
#  '16.sütun , rev.no: rev.no:',
#  '17.sütun , s-1 / 1 - 1',
#  '18.sütun , (d (d']

# %%
import ollama
import chromadb

client = chromadb.Client()


collection = client.get_or_create_collection(name="lines")
for i, d in enumerate(lines):
    response = ollama.embeddings(model="nomic-embed-text", prompt=d)
    embedding = response["embedding"]
    collection.add(ids=[str(i)],embeddings=[embedding],documents=[d])


collection = client.get_or_create_collection(name="columns")
for i, d in enumerate(columns):
    response = ollama.embeddings(model="nomic-embed-text", prompt=d)
    embedding = response["embedding"]
    collection.add(ids=[str(i)],embeddings=[embedding],documents=[d])




def send_request(req):
    prompt = req

    collection = client.get_or_create_collection(name="lines")
    response = ollama.embeddings(prompt=prompt,model="nomic-embed-text")
    results = collection.query(query_embeddings=[response["embedding"]],n_results=10)
    data_lines = results['documents'][0]
    
    collection = client.get_or_create_collection(name="columns")
    response = ollama.embeddings(prompt=prompt,model="nomic-embed-text")
    results = collection.query(query_embeddings=[response["embedding"]],n_results=10)
    data_columns = results['documents'][0]
    
    
    output = ollama.generate(model="gemma2",prompt=f"{prompt}, bu soruyu cevaplayabilmek için önce Bu bilgileri incele: {data_lines}, eğer yeterli bir cevap bulamazsan bunu incele: {data_columns} , EN mantıklı! ve EN kısa! cevabı ver")
    return (output['response'])

while True:
   req = input("soru: ")
   req = req.lower()
   print(send_request(req))
# Out:
# Alici Nursel Ata'dır. T.C. Kimlik numarası 14321632406'dır.
#
#
# Bu bilgi metninde alıcının adı ve kimlik numarası açıkça belirtilmiştir.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 43
#      41 req = input("soru: ")
#      42 req = req.lower()
# ---> 43 print(send_request(req))
#
# Cell In[4], line 28, in send_request(req)
#      26 collection = client.get_or_create_collection(name="lines")
#      27 response = ollama.embeddings(prompt=prompt,model="nomic-embed-text")
# ---> 28 results = collection.query(query_embeddings=[response["embedding"]],n_results=10)
#      29 data_lines = results['documents'][0]
#      31 collection = client.get_or_create_collection(name="columns")
#
# File c:\Users\arda\AppData\Local\Programs\Python\Python312\Lib\site-packages\chromadb\api\models\Collection.py:184, in Collection.query(self, query_embeddings, query_texts, query_images, query_uris, n_results, where, where_document, include)
#     141 def query(
#     142     self,
#     143     query_embeddings: Optional[  # type: ignore[type-arg]
#    (...)
#     155     include: Include = ["metadatas", "documents", "distances"],
#     156 ) -> QueryResult:
#     157     """Get the n_results nearest neighbor embeddings for provided query_embeddings or query_texts.
#     158
#     159     Args:
#    (...)
#     176
#     177     """
#     179     (
#     180         valid_query_embeddings,
#     181         valid_n_results,
#     182         valid_where,
#     183         valid_where_document,
# --> 184     ) = self._validate_and_prepare_query_request(
#     185         query_embeddings,
#     186         query_texts,
#     187         query_images,
#     188         query_uris,
#     189         n_results,
#     190         where,
#     191         where_document,
#     192         include,
#     193     )
#     195     query_results = self._client._query(
#     196         collection_id=self.id,
#     197         query_embeddings=valid_query_embeddings,
#    (...)
#     201         include=include,
#     202     )
#     204     return self._transform_query_response(query_results, include)
#
# File c:\Users\arda\AppData\Local\Programs\Python\Python312\Lib\site-packages\chromadb\api\models\CollectionCommon.py:368, in CollectionCommon._validate_and_prepare_query_request(self, query_embeddings, query_texts, query_images, query_uris, n_results, where, where_document, include)
#     363 valid_where = validate_where(where) if where else {}
#     364 valid_where_document = (
#     365     validate_where_document(where_document) if where_document else {}
#     366 )
#     367 valid_query_embeddings = (
# --> 368     validate_embeddings(
#     369         self._normalize_embeddings(
#     370             maybe_cast_one_to_many_embedding(query_embeddings)
#     371         )
#     372     )
#     373     if query_embeddings is not None
#     374     else None
#     375 )
#     376 valid_query_texts = (
#     377     maybe_cast_one_to_many_document(query_texts)
#     378     if query_texts is not None
#     379     else None
#     380 )
#     381 valid_query_images = (
#     382     maybe_cast_one_to_many_image(query_images)
#     383     if query_images is not None
#     384     else None
#     385 )
#
# File c:\Users\arda\AppData\Local\Programs\Python\Python312\Lib\site-packages\chromadb\api\types.py:514, in validate_embeddings(embeddings)
#     512 for i, embedding in enumerate(embeddings):
#     513     if len(embedding) == 0:
# --> 514         raise ValueError(
#     515             f"Expected each embedding in the embeddings to be a non-empty list, got empty embedding at pos {i}"
#     516         )
#     517     if not all(
#     518         [
#     519             isinstance(value, (int, float)) and not isinstance(value, bool)
#     520             for value in embedding
#     521         ]
#     522     ):
#     523         raise ValueError(
#     524             "Expected each value in the embedding to be a int or float, got an embedding with "
#     525             f"{list(set([type(value).__name__ for value in embedding]))} - {embedding}"
#     526         )
#
# ValueError: Expected each embedding in the embeddings to be a non-empty list, got empty embedding at pos 0
